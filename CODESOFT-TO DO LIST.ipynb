# %% [markdown]
# ## TASK - 3

# %% [markdown]
# ## TO DO LIST

# %%
# This implementation allows you to add tasks, view the tasks in the list, mark tasks as completed, and remove tasks from the list.

class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task):
        self.tasks.append(task)
        print(f"Task '{task}' added to the list.")

    def view_tasks(self):
        if self.tasks:
            print("To-Do List:")
            for index, task in enumerate(self.tasks, start=1):
                print(f"{index}. {task}")
        else:
            print("Your To-Do List is empty.")

    def mark_completed(self, task_index):
        if 1 <= task_index <= len(self.tasks):
            task = self.tasks[task_index - 1]
            print(f"Task '{task}' marked as completed.")
        else:
            print("Invalid task index.")

    def remove_task(self, task_index):
        if 1 <= task_index <= len(self.tasks):
            task = self.tasks.pop(task_index - 1)
            print(f"Task '{task}' removed from the list.")
        else:
            print("Invalid task index.")


def main():
    todo_list = ToDoList()

    while True:
        print("\n--- To-Do List Menu ---")
        print("1. Add Task")
        print("2. View Tasks")
        print("3. Mark Task as Completed")
        print("4. Remove Task")
        print("5. Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            task = input("Enter the task: ")
            todo_list.add_task(task)
        elif choice == '2':
            todo_list.view_tasks()
        elif choice == '3':
            task_index = int(input("Enter the task number to mark as completed: "))
            todo_list.mark_completed(task_index)
        elif choice == '4':
            task_index = int(input("Enter the task number to remove: "))
            todo_list.remove_task(task_index)
        elif choice == '5':
            print("Exiting the To-Do List.")
            break
        else:
            print("Invalid choice. Please try again.")


if __name__ == "__main__":
    main()
# Out:
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 1
# Enter the task: Make a list of students
# Task 'Make a list of students' added to the list.
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 1
# Enter the task: TAKE PHOTOS OF ALL STUDENTS
# Task 'TAKE PHOTOS OF ALL STUDENTS' added to the list.
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): TAKE SIGN OF ALL STUDENTS
# Invalid choice. Please try again.
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 3
# Enter the task number to mark as completed: 2
# Task 'TAKE PHOTOS OF ALL STUDENTS' marked as completed.
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 2
# To-Do List:
# 1. Make a list of students
# 2. TAKE PHOTOS OF ALL STUDENTS
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 4
# Enter the task number to remove: 1
# Task 'Make a list of students' removed from the list.
#
# --- To-Do List Menu ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 5
# Exiting the To-Do List.
